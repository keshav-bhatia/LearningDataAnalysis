# %% [markdown]
# # MATPLOTLIB 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
#plottling using matplotlib
plt.scatter(x,y,c='b')
plt.xlabel('X axis')
plt.xlabel('Y axis')
plt.title('Graph in 2D')
# plt.savefig('test.png')   FOR SAVING PLOT IMAGE IN THE DIRECTORY
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
y=x*x

# %%
#plt plot
plt.plot(x,y,'ro',linestyle='dashed',linewidth=2,markersize=2)

#extras
plt.xlabel('X axis')
plt.xlabel('Y axis')
plt.title(' 2D')
# Out:
# Text(0.5, 1.0, ' 2D')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')

plt.subplot(2,2,2)
plt.plot(x,y,'b')

plt.subplot(2,2,3)
plt.plot(x,y,'g')

# %%
#More examples-1
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
            #SIN WAVE FUNCTION PLOT

# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.title("sine wave form")

# %%
            #Subplot for the sine and cosine curve()

# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
#plt.show()
# Out:
# Text(0.5, 1.0, 'Cosine')

# %%
            #BAR PLOT

x=[2,10,9]
y=[11,12,14]

x2=[4,7,8]
y2=[8,7,14]

plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g')
plt.title('bar graph')
plt.ylabel('y axis')
plt.xlabel('x axis')
# Out:
# Text(0.5, 0, 'x axis')

# %%
        #HISTOGRAM

a=np.array([14,25,21,1,25,13,2,8,9,5,41,26,35,15,24])
plt.hist(a)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
                #BOX PLOT


data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False);

# %%
data
# Out:
# [array([-1.05391347,  0.1804398 ,  1.41483966, -1.5550895 ,  0.97125   ,
#          0.3205305 , -0.20820854,  0.70458727,  0.19614225,  1.04749866,
#          0.26309032,  0.30171727, -1.22950835, -0.72199151, -1.20944846,
#         -0.63246341,  1.40475365,  1.25689211,  0.48171657,  0.78822426,
#         -0.11129981,  0.41823238, -0.33729069,  0.533322  ,  0.11898516,
#          1.24914982,  1.43800616,  1.89733072,  1.75540408, -1.09254279,
#          0.44503886, -1.43253512,  1.74870971, -0.71750006, -1.10323223,
#         -0.95354906,  1.72340598,  0.55394648,  1.06898053, -0.29207506,
#          1.49963252, -0.28775186, -0.42137876, -1.52589703, -0.47845439,
#          0.06091201, -0.28103296,  0.27426681, -0.39339551,  0.24121336,
#          2.17654086,  0.98204746, -0.60215509,  0.31951248, -1.47204503,
#          0.55860001,  0.52945137,  0.17609298, -0.62316665,  1.52759349,
#         -1.29745886,  0.13051995,  0.26498441, -0.03319865, -0.30731376,
# ...

# %%
                                    #PIE CHART

    
    # Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False)

plt.axis('equal')
plt.show()
